# %%
import csv 
import sys 
from pathlib import Path 
from typing import Dict, List, Tuple, Optional
import os 

if "__file__" in globals():
    PROJECT_ROOT = Path(__file__).resolve().parents[1]
else:
    PROJECT_ROOT = Path(os.getcwd())
# PROJECT_ROOT = Path(__file__).resolve().parents[1]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

def get_pair_detail(csv_path: Path) -> List[Dict]:
    """Load pair csv from relative path"""
    record = []
    with csv_path.open("r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        for row in reader:
            record.append(row)
    return record

# %%
out_root = PROJECT_ROOT / "outputs"
train_pair_path = out_root / "pairs" / "val_pairs.csv"

# %%
# train_pair_path = "/outputs/pairs/train_pairs.csv"
# train_pair_path = f"/Users/nandanprince/Desktop/facial_recognition/outputs/pairs/val_pairs.csv"

# %%
x = get_pair_detail(train_pair_path)

# %%
len(x)
# Out:
# 6000
